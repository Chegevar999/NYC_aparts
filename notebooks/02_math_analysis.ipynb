# %% [markdown]
# # 02 Математико-статистический анализ

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
df = pd.read_csv(ROOT / "data" / "processed" / "clean_real_estate_with_clusters.csv")
ml_cols = ["LotArea","OverallQual","OverallCond","YearBuilt","GrLivArea","FullBath","GarageCars","GarageArea","TotalBsmtSF","TotRmsAbvGrd"]
df[ml_cols].describe().T

# %%
df[ml_cols].var()

# %%
corr = df[ml_cols].corr()
corr

# %% [markdown]
# Вывод: статистический анализ показывает различия по площади, качеству, гаражу и году постройки. Эти признаки подходят для кластеризации.

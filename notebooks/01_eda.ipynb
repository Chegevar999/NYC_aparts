# %% [markdown]
# # 01 EDA — первичный анализ данных

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
df = pd.read_csv(ROOT / "data" / "raw" / "test.csv")
df.head()

# %%
df.shape, df.dtypes.value_counts()

# %%
missing = df.isna().sum().sort_values(ascending=False)
missing[missing > 0].head(20)

# %%
df.duplicated().sum()

# %%
df.describe().T.head(20)

# %% [markdown]
# Первые выводы: данные содержат числовые и категориальные признаки недвижимости; есть пропуски; для ML без SalePrice выбрана кластеризация.
